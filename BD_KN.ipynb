-- %% [markdown]
-- # [BD_KN]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [BD_KN]    Script Date: 30/09/2025 07:37:24 p. m. ******/
CREATE DATABASE [BD_KN]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'BD_KN', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS02\MSSQL\DATA\BD_KN.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'BD_KN_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS02\MSSQL\DATA\BD_KN_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [BD_KN] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [BD_KN].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [BD_KN] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [BD_KN] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [BD_KN] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [BD_KN] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [BD_KN] SET ARITHABORT OFF 
GO
ALTER DATABASE [BD_KN] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [BD_KN] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [BD_KN] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [BD_KN] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [BD_KN] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [BD_KN] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [BD_KN] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [BD_KN] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [BD_KN] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [BD_KN] SET  DISABLE_BROKER 
GO
ALTER DATABASE [BD_KN] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [BD_KN] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [BD_KN] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [BD_KN] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [BD_KN] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [BD_KN] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [BD_KN] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [BD_KN] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [BD_KN] SET  MULTI_USER 
GO
ALTER DATABASE [BD_KN] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [BD_KN] SET DB_CHAINING OFF 
GO
ALTER DATABASE [BD_KN] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [BD_KN] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [BD_KN] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [BD_KN] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [BD_KN] SET QUERY_STORE = ON
GO
ALTER DATABASE [BD_KN] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[T_Perfiles]

-- %%
USE [BD_KN]
GO

-- %%
/****** Object:  Table [dbo].[T_Perfiles]    Script Date: 30/09/2025 07:37:24 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[T_Perfiles](
	[ConsecutivoPerfil] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](100) NOT NULL,
 CONSTRAINT [PK_T_Perfil] PRIMARY KEY CLUSTERED 
(
	[ConsecutivoPerfil] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[T_Usuarios]

-- %%
/****** Object:  Table [dbo].[T_Usuarios]    Script Date: 30/09/2025 07:37:24 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[T_Usuarios](
	[ConsecutivoUsuario] [bigint] IDENTITY(1,1) NOT NULL,
	[Identificacion] [varchar](15) NOT NULL,
	[Nombre] [varchar](255) NOT NULL,
	[CorreoElectronico] [varchar](100) NOT NULL,
	[Contrasenna] [varchar](15) NOT NULL,
	[Estado] [bit] NOT NULL,
	[ConsecutivoPerfil] [int] NOT NULL,
 CONSTRAINT [PK_T_Usuarios] PRIMARY KEY CLUSTERED 
(
	[ConsecutivoUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[T_Perfiles]

-- %%
SET IDENTITY_INSERT [dbo].[T_Perfiles] ON 
INSERT [dbo].[T_Perfiles] ([ConsecutivoPerfil], [Nombre]) VALUES (1, N'Administrador')
INSERT [dbo].[T_Perfiles] ([ConsecutivoPerfil], [Nombre]) VALUES (2, N'Regular')
SET IDENTITY_INSERT [dbo].[T_Perfiles] OFF
GO

-- %% [markdown]
-- # [FK_T_Usuarios_T_Perfil]

-- %%
ALTER TABLE [dbo].[T_Usuarios]  WITH CHECK ADD  CONSTRAINT [FK_T_Usuarios_T_Perfil] FOREIGN KEY([ConsecutivoPerfil])
REFERENCES [dbo].[T_Perfiles] ([ConsecutivoPerfil])
GO
ALTER TABLE [dbo].[T_Usuarios] CHECK CONSTRAINT [FK_T_Usuarios_T_Perfil]
GO

-- %% [markdown]
-- # [BD_KN]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [BD_KN] SET  READ_WRITE 
GO
